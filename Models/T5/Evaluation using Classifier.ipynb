# %% [markdown]
# Collab Link : https://colab.research.google.com/drive/1F0xBz3vV6JPEdM4Dl9WcPV7WhP-mWZ60?usp=sharing

# %% [markdown]
# # This Notebook contains code to evalutate the paraphrases generated by our fine tuned T5 model by using our fine tuned BERT Classifier

# %% [markdown]
# # Imports

# %%
# !pip install --quiet transformers
# !pip install --quiet tokenizers
# !pip install --quiet sentencepiece
# !pip install --quiet torchtext torch
# !pip install --quiet pytorch_lightning
# Out:
#      |████████████████████████████████| 3.1 MB 13.5 MB/s
#      |████████████████████████████████| 3.3 MB 34.5 MB/s
#      |████████████████████████████████| 59 kB 6.7 MB/s
#      |████████████████████████████████| 895 kB 43.7 MB/s
#      |████████████████████████████████| 596 kB 52.8 MB/s
#      |████████████████████████████████| 1.2 MB 12.7 MB/s
#      |████████████████████████████████| 1.0 MB 12.7 MB/s
#      |████████████████████████████████| 829 kB 31.3 MB/s
#      |████████████████████████████████| 132 kB 33.7 MB/s
#      |████████████████████████████████| 329 kB 37.3 MB/s
#      |████████████████████████████████| 1.1 MB 42.3 MB/s
#      |████████████████████████████████| 271 kB 52.6 MB/s
#      |████████████████████████████████| 160 kB 50.1 MB/s
#      |████████████████████████████████| 192 kB 51.7 MB/s
#   Building wheel for future (setup.py) ... done

# %%
from tabulate import tabulate

# %%
import random
import pandas as pd
import numpy as np

from tqdm.auto import tqdm
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader

from transformers import BertTokenizerFast as BertTokenizer, BertModel
import pytorch_lightning as pl

from pytorch_lightning.plugins import DDPPlugin

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, multilabel_confusion_matrix
from sklearn.metrics import accuracy_score,f1_score,roc_curve
from transformers import T5ForConditionalGeneration,T5Tokenizer
from tqdm import tqdm

# %%
from google.colab import drive
drive.mount('/content/drive',force_remount=True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Paraphrase Classifier

# %% [markdown]
# ## Bert Class

# %%
class BertParaphrase(pl.LightningModule):

  def __init__(self):
    super().__init__()
    self.model =  BertModel.from_pretrained( 'bert-base-cased' ,return_dict=True)
    self.classifier = nn.Linear(self.model.config.hidden_size, 1)
    self.criterion = nn.BCELoss()
    self.relu = nn.ReLU()
    self.layer_1 = nn.Linear(self.model.config.hidden_size , self.model.config.hidden_size)

  def forward(self, input_ids, attention_mask, labels=None):
  
    output = self.model(input_ids, attention_mask=attention_mask)
    output = self.layer_1(output.pooler_output)
    output = self.relu(output)
    output = self.classifier(output)
    output = torch.sigmoid(output)
    
    loss = 0

    if labels is not None:
        loss = self.criterion(output, labels)
    return loss, output

# %% [markdown]
# ## Tokenizer

# %%
tokenizer = BertTokenizer.from_pretrained('bert-base-cased')
# Out:
# Downloading:   0%|          | 0.00/208k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/426k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/29.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/570 [00:00<?, ?B/s]

# %% [markdown]
# ## Load the model form checkpoint

# %%
bert_model = BertParaphrase.load_from_checkpoint("drive/MyDrive/IRE/Classifer/classfier.ckpt")
bert_model.to("cuda")
bert_model.eval()
bert_model.freeze()
# Out:
# Downloading:   0%|          | 0.00/416M [00:00<?, ?B/s]
# Some weights of the model checkpoint at bert-base-cased were not used when initializing BertModel: ['cls.predictions.transform.dense.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %% [markdown]
# # Generate Predictions

# %%
def get_prediction(trained_model , sentence , paraphrase):
  enc = tokenizer.encode_plus(
      sentence,
      paraphrase,
      add_special_tokens=True,
      max_length=120,
      return_token_type_ids=False,
      padding="max_length",
      return_attention_mask=True,
      return_tensors='pt',
    )
  
  _,prediction = trained_model(enc["input_ids"].to("cuda"), enc["attention_mask"].to("cuda"))
  prediction = prediction.flatten().cpu().numpy()
  pred_label = prediction[0] > 0.8
  pred_label = pred_label * 1
  return pred_label

# %% [markdown]
# # Paraphrase Generator

# %%
t5_tokenizer = T5Tokenizer.from_pretrained('t5-base')
t5_model = T5ForConditionalGeneration.from_pretrained('./drive/MyDrive/IRE/Final_t5_parphrase')
t5_model.to("cuda")

# %% [markdown]
# # Generate Paraphrases

# %%
def generate(model, tokenizer, sentence):


  text = "paraphrase: " + sentence
  max_len = 256

  encoding = tokenizer.encode_plus(text,padding='max_length', return_tensors="pt")
  input_ids, attention_masks = encoding["input_ids"].to("cuda"), encoding["attention_mask"].to("cuda")
  

  outputs = model.generate(
    input_ids=input_ids, 
    attention_mask=attention_masks,
    do_sample=True,
    max_length=256,
    top_k=220,
    top_p=0.9,
    early_stopping=True,
    num_return_sequences=20
  )



  final_outputs = []

  for output in outputs:
      sent = tokenizer.decode(output, skip_special_tokens=True,clean_up_tokenization_spaces=True)
      if sent.lower() != sentence.lower() and sent not in final_outputs:
          final_outputs.append(sent) 

  
  return final_outputs

# %% [markdown]
# # Data for Evaluation

# %%
df = pd.read_csv("../../PAWS_dataset/paws_test.csv")
total_data = list(df['sentence1'])

# %%
data = random.sample(total_data, 1000)

# %%
def generate_score_data(data):

    sum_of_average = 0
    all_paraphrases = []
    table_data = []

    for sentence in tqdm(data):
        paraphrases = generate(t5_model ,t5_tokenizer, sentence)
        curr_data = []
        not_paraphrase = 0        
        for output in paraphrases:
            prediction = get_prediction(bert_model, sentence, output)
            if(prediction == 0): not_paraphrase += 1
            curr_data.append([output, prediction])
        sum_of_average +=  1 - (not_paraphrase)/ (len(paraphrases))
        table_data.append(curr_data) 
    
    final_score = sum_of_average / (len(data))

    for i in range(10):
        sentence = data[i]
        print()
        print("INPUT SENTENCE IS : ")
        print(sentence)
        print()
        print("GENERATE PARAPHRASE AND CLASSIFER PREDICTION : ")
        print()
        print(tabulate(table_data[i], headers=['Paraphrase', 'Classifier Prediction'],tablefmt='orgtbl'))
        print()
        print('=====================================================================================================')            

    return final_score

# %%
final_score = generate_score_data(data)
# Out:
# 100%|██████████| 1000/1000 [48:38<00:00,  2.92s/it]
# INPUT SENTENCE IS :
# Both electromagnetic brakes and eddy current brakes use electromagnetic force but electromagnetic brakes ultimately depend on friction and eddy current brakes use magnetic force directly .
#
# GENERATE PARAPHRASE AND CLASSIFER PREDICTION :
#
# | Paraphrase                                                                                                                                                                                      |   Classifier Prediction |
# |-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------------------|
# | Both electromagnetic brakes and eddy current brakes use electromagnetic force, but electromagnetic brakes ultimately depend on friction and eddy current brakes use magnetic force directly.    |                       1 |
# | Both electromagnetic brakes and eddy current brakes use electromagnetic force, but electromagnetic brakes ultimately depend on friction, and eddy current brakes use magnetic force directly.   |                       1 |
# | Both electromagnetic brakes and eddy current brakes use electromagnetic force, electromagnetic brakes ultimately depend on friction, while eddy current brakes use magnetic force directly.     |                       1 |
# | Both electromagnetic brakes and eddy current brakes use electromagnetic force but electromagnetic brakes ultimately depend on friction and eddy current brakes use magnetic force directly.     |                       1 |
# | Both electromagnetic brakes and eddy current brakes use electromagnetic force, but electromagnetic brakes ultimately depend on friction, and eddy current brakes directly use magnetic force.   |                       1 |
# | Both electromagnetic brakes and eddy current brakes use electromagnetic force, electromagnetic brakes ultimately depend on friction, and eddy current brakes use magnetic force directly.       |                       1 |
# | Both electromagnetic brakes and eddy current brakes use electromagnetic force, but electromagnetic brakes ultimately depend on friction, while eddy current brakes use magnetic force directly. |                       1 |
# | Both electromagnetic brakes and eddy current brakes use electromagnetic force, but electromagnetic brakes depend on friction, and eddy current brakes use magnetic force directly.              |                       1 |
# | Both electromagnetic brakes and eddy current brakes use electromagnetic force, electromagnetic brakes ultimately depend on friction and eddy current brakes use magnetic force directly.        |                       1 |
#
# =====================================================================================================
#
# INPUT SENTENCE IS :
# Despite the advantages of mini effects , FAB effects are more fragile : the mini effects are less common , but the plastic construction makes them expensive .
#
# GENERATE PARAPHRASE AND CLASSIFER PREDICTION :
#
# | Paraphrase                                                                                                                                                       |   Classifier Prediction |
# |------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------------------|
# | Despite the advantages of mini effects, FAB effects are more fragile : the mini effects are less common but the plastic construction makes them costly.          |                       1 |
# | Despite the advantages of mini effects, FAB effects are more fragile : the mini effects are less common but plastic construction makes them expensive.           |                       1 |
# | Despite the advantages of mini effects, FAB effects are more fragile : mini effects are less common but plastic construction makes them expensive.               |                       1 |
# | Despite the advantages of mini effects, FAB effects are more fragile : the mini effects are less common, but plastic construction makes them expensive.          |                       1 |
# | Despite the advantages of mini effects, FAB effects are more fragile : the mini effects are less common, but plastic construction makes them costly.             |                       1 |
# | Despite the advantages of mini effects, FAB effects are more fragile : the mini effects are less common, but the plastic construction makes them expensive.      |                       1 |
# | Despite the advantages of mini effects, FAB effects are more fragile : the mini effects are less common but the plastic construction makes them expensive.       |                       1 |
# | Despite the advantages of Mini effects, FAB effects are more fragile : Mini effects are less common, but the plastic construction makes them expensive.          |                       1 |
# | Despite the advantages of mini effects, FAB effects are more fragile : mini effects are less common, but plastic construction makes them expensive.              |                       1 |
# | FAB effects are more fragile, despite the advantages of mini effects : they are less common, but the plastic construction makes them expensive.                  |                       1 |
# | Despite the advantages of mini effects, FAB effects are more fragile : mini effects are less common, but the plastic construction makes them expensive.          |                       1 |
# | Despite the advantages of mini effects, FAB effects are more fragile : the mini effects are less common, but plastic construction makes them more expensive.     |                       1 |
# | Despite the advantages of Mini effects, FAB effects are more fragile : the mini effects are less common, but the plastic construction makes them more expensive. |                       1 |
# | Despite the advantages of mini effects, FAB effects are more fragile : the mini effects are less common, but the plastic construction makes them costly.         |                       1 |
#
# =====================================================================================================
#
# INPUT SENTENCE IS :
# It is being revealed here that Lionel Charlie and Nana were killed .
#
# GENERATE PARAPHRASE AND CLASSIFER PREDICTION :
#
# | Paraphrase                                                                     |   Classifier Prediction |
# |--------------------------------------------------------------------------------+-------------------------|
# | It is revealed that Lionel Charlie and Nana were killed.                       |                       1 |
# | It is being revealed here that Lionel Charlie and Nana were killed.            |                       1 |
# | It is revealed here that Lionel Charlie and Nana were killed.                  |                       1 |
# | It is being revealed here that Lionel Charlie and Nana were murdered.          |                       1 |
# | Here, it is revealed that Lionel Charlie and Nana were killed.                 |                       1 |
# | It is revealed that Lionel Charlie and Nana were killed in this investigation. |                       1 |
# | It is being revealed that Lionel Charlie and Nana were killed.                 |                       1 |
#
# =====================================================================================================
#
# INPUT SENTENCE IS :
# According to the United States Census Bureau , Ardmore has a total area of , of which is land and , or 3.67 % , is water .
#
# GENERATE PARAPHRASE AND CLASSIFER PREDICTION :
#
# | Paraphrase                                                                                                               |   Classifier Prediction |
# |--------------------------------------------------------------------------------------------------------------------------+-------------------------|
# | According to the United States Census Bureau, Ardmore has a total area of, of which land and of which, or 3.67 %, water. |                       1 |
# | According to the United States Census Bureau, Ardmore has a total area of, of which is land and, or 3.67 %, is water.    |                       1 |
# | According to the United States Census Bureau, Ardmore has a total area of, of which is land and is water, or 3.67 %.     |                       1 |
# | According to the United States Census Bureau, Ardmore has a total area of, of which is land and, or 3.67 %, water.       |                       1 |
# | According to the United States Census Bureau, Ardmore has a total area, of which is land and, or 3.67 %, is water.       |                       1 |
#
# =====================================================================================================
#
# INPUT SENTENCE IS :
# The Soviet Union was officially neutral until June 1941 in Asia , and until August 1945 in Europe , when it attacked Japan in cooperation with the U.S .
#
# GENERATE PARAPHRASE AND CLASSIFER PREDICTION :
#
# | Paraphrase                                                                                                                                                      |   Classifier Prediction |
# |-----------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------------------|
# | The Soviet Union was neutral in Asia until June 1941 and in Europe until August 1945 when it attacked Japan in cooperation with the U.S.                        |                       1 |
# | The Soviet Union was officially neutral until June 1941 in Asia, and until August 1945 in Europe, when it attacked Japan in cooperation with the United States. |                       1 |
# | The Soviet Union was officially neutral until June 1941 in Asia and until August 1945 in Europe, when it attacked Japan in cooperation with the United States.  |                       1 |
# | The Soviet Union was officially neutral in Asia until June 1941, and in Europe until August 1945 when it attacked Japan in cooperation with the U.S.            |                       1 |
# | The Soviet Union was officially neutral until June 1941 in Asia and until August 1945 in Europe, when it attacked Japan in cooperation with the U.S.            |                       1 |
# | The Soviet Union was officially neutral in Asia until June 1941, and until August 1945 in Europe, when it attacked Japan in cooperation with the U.S.           |                       1 |
# | The Soviet Union was officially neutral in Asia until June 1941 and until August 1945 in Europe when it attacked Japan in cooperation with the U.S.             |                       1 |
# | The Soviet Union was neutral until June 1941 in Asia, and until August 1945 in Europe, when it attacked Japan in cooperation with the United States.            |                       1 |
# | The Soviet Union was officially neutral in Asia until June 1941 and until August 1945 in Europe, when it attacked Japan in cooperation with the United States.  |                       1 |
# | The Soviet Union was officially neutral until June 1941 in Asia, and until August 1945 in Europe, when it attacked Japan in cooperation with the U.S.           |                       1 |
#
# =====================================================================================================
#
# INPUT SENTENCE IS :
# What are the top best psychological movies?
#
# GENERATE PARAPHRASE AND CLASSIFER PREDICTION :
#
# | Paraphrase                                           |   Classifier Prediction |
# |------------------------------------------------------+-------------------------|
# | What are the top psychological movies?               |                       1 |
# | Which are the best psychological movies ever?        |                       1 |
# | Which are the best psychological movies of all time? |                       1 |
# | What are the best psychological movies of all time?  |                       1 |
# | What are the best psychological films?               |                       1 |
# | What are some of the best psychological films?       |                       1 |
# | What is the top psychological movie ever made?       |                       1 |
# | What are the best psychological movies?              |                       1 |
# | What are some of the best psychological movies?      |                       1 |
# | What are the top 10 psychological movies?            |                       1 |
# | What is the best psychological movie in 2019?        |                       1 |
# | What are the top psychological films?                |                       1 |
# | What is the best psychological movie ever made?      |                       1 |
# | Which is the best psychological film you can see?    |                       1 |
# | Which is the best psychological movie in the world?  |                       1 |
# | Which is the best psychological movie?               |                       1 |
#
# =====================================================================================================
#
# INPUT SENTENCE IS :
# It was rebuilt in 1940 during the Manchester flash and finally destroyed .
#
# GENERATE PARAPHRASE AND CLASSIFER PREDICTION :
#
# | Paraphrase                                                                       |   Classifier Prediction |
# |----------------------------------------------------------------------------------+-------------------------|
# | It was rebuilt in 1940 during the Manchester flash and eventually destroyed.     |                       1 |
# | It was rebuilt during the Manchester flash in 1940 and eventually destroyed.     |                       1 |
# | It was rebuilt in 1940 during the Manchester flash and destroyed.                |                       1 |
# | It was rebuilt in 1940 during the Manchester flash and finally destroyed.        |                       1 |
# | It was rebuilt during the Manchester flash in 1940 and finally destroyed.        |                       1 |
# | It was rebuilt in 1940 during the Manchester flash, and finally destroyed.       |                       1 |
# | It was rebuilt during the Manchester flash in 1940 and was ultimately destroyed. |                       1 |
# | It was rebuilt in 1940 during the Manchester flash and was destroyed.            |                       1 |
# | It was rebuilt in 1940 during the Manchester flash and then destroyed.           |                       1 |
# | It was rebuilt in 1940 during the Manchester flash and was eventually destroyed. |                       1 |
# | In 1940, during the Manchester flash, it was rebuilt and finally destroyed.      |                       1 |
#
# =====================================================================================================
#
# INPUT SENTENCE IS :
# Which Books should I prefer for IIT-JAM Physics preparation?
#
# GENERATE PARAPHRASE AND CLASSIFER PREDICTION :
#
# | Paraphrase                                                   |   Classifier Prediction |
# |--------------------------------------------------------------+-------------------------|
# | Which books should I use for IIT-JAM Physics preparation?    |                       1 |
# | Which books should I select for IIT JAM Physics?             |                       1 |
# | Which books should I prefer for my IIT JAM Physics exam?     |                       1 |
# | Which are the best books for IIT-JAM Physics preparation?    |                       1 |
# | Which are some good book to study for IIT-JAM Physics?       |                       1 |
# | Which are best books to read for IIT-JAM Physics?            |                       1 |
# | Which book should I choose for my IIT JAM Physics?           |                       1 |
# | Which are the best books for IIT physics preparation?        |                       1 |
# | Which books are better for IIT-JAM Physics?                  |                       1 |
# | Which books are best for IIT-JAM Physics preparation?        |                       1 |
# | Which book should I choose for IIT-JAM Physics preparation?  |                       1 |
# | Which books should I choose for IIT-JAM Physics preparation? |                       1 |
# | Which is the best book to nab for IIT JAM Physics study?     |                       1 |
# | Which books should I prefer for IIT JAM Physics preparation? |                       1 |
# | Which books will I prefer for IIT-JAM Physics?               |                       1 |
# | Which books are the best for IIT-JAM Physics preparation?    |                       1 |
# | Which is the best for IIT-JAM Physics preparation?           |                       0 |
# | Which is the best book for IITJAM Physics preparation?       |                       1 |
# | Which are best books for IIT JAM Physics preparation?        |                       1 |
#
# =====================================================================================================
#
# INPUT SENTENCE IS :
# Doyline is an entry point to Lake Bistineau and the Bistineau State Park .
#
# GENERATE PARAPHRASE AND CLASSIFER PREDICTION :
#
# | Paraphrase                                                                    |   Classifier Prediction |
# |-------------------------------------------------------------------------------+-------------------------|
# | Doyline is an entry point to Lake Bistineau and the Bistineau State Park.     |                       1 |
# | Doyline is an entry point to Lake Bistineau and Bistineau State Park.         |                       1 |
# | Doyline is an entry point to the Bistineau lake and the Bistineau State Park. |                       1 |
# | Doyline is an entrance point to Lake Bistineau and the Bistineau State Park.  |                       1 |
# | Doyline is an entry point to the Bistineau Lake and the Bistineau State Park. |                       1 |
# | Doyline is an entrance point to Lake Bistineau and to Bistineau State Park.   |                       1 |
#
# =====================================================================================================
#
# INPUT SENTENCE IS :
# You have Rs. 10,000/-. In which Mutual fund in India you would be investing in for Maximum 3-6 Month Period and Why? Also suggest any Alternative if any other than Mutual Fund.
#
# GENERATE PARAPHRASE AND CLASSIFER PREDICTION :
#
# | Paraphrase                                                                                                                                                                              |   Classifier Prediction |
# |-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------------------|
# | What is the best Mutual fund to invest in for 3-6 months?                                                                                                                               |                       0 |
# | In which Mutual Funds is India you would invest in for maximum 3-6 Month period and why?                                                                                                |                       1 |
# | In which mutual fund in India you would be investing in for maximum 3-6 months and why?                                                                                                 |                       1 |
# | You have Rs. 10,000/-. In which mutual fund would you be investing in for 3-6 months and Why? Also suggest any other alternative than mutual fund?                                      |                       1 |
# | I have Rs. 10,000 and in which mutual fund in India would I invest for maximum 3-6 Months? Also suggest any alternative if any other than Mutual Fund?                                  |                       1 |
# | Should I invest Rs. 10,000/- in the Mutual fund?                                                                                                                                        |                       0 |
# | The average personal income is Rs. 10,000/-. In which Mutual Fund in India do you invest for maximum 3-6 Months period?                                                                 |                       0 |
# | You have 10,000/-. Which is the best mutual fund in India for maximum 3-6 Month period? And why?                                                                                        |                       1 |
# | If you have 10,000/- in your portfolio, in which mutual fund in India would you be investing for Maximum 3-6 Month Period and why? Also suggest any alternative other than Mutual Fund. |                       1 |
# | What is the Mutual fund in India which you would be investing in for a maximum period of 3-6 months and why? Also suggest any other alternative than Mutual Fund?                       |                       1 |
# | How much is the maximum amount of money you would invest in your upcoming Mutual Funds?                                                                                                 |                       0 |
# | In which Mutual Fund in India you would be investing for maximum 3-6 Months and Why? Also, suggest any alternative if any other than mutual fund.                                       |                       1 |
# | What mutual fund would you invest in for a maximum period of 3-6 months?                                                                                                                |                       0 |
# | If you are in Rs. 10,000/-, in which Mutual Fund in India you would be investing for maximum 3-6 Month period and why?                                                                  |                       1 |
# | In which mutual fund of India you would be investing in for 3-6 months? Also suggest any Alternative if any other than Mutual Fund.                                                     |                       1 |
# | If you have 10,000/- in your account, which Mutual Fund in India you would be investing for a period of minimum 3-6 months?                                                             |                       1 |
# | In which Mutual Fund in India would you invest for maximum period of 3-6 Months and Why? Also suggest any alternative, if any.                                                          |                       1 |
# | Which is the most popular mutual fund in India?                                                                                                                                         |                       0 |
# | You have RM 10,000/-. Which Mutual Fund in India would you invest for maximum 3-6 Month period and why? Also suggest any other alternative than Mutual Fund.                            |                       1 |
# | How many crores you would be investing for a maximum of 3 months in your Mutual Fund in India?                                                                                          |                       0 |
#
# =====================================================================================================

# %%
print(final_score)
# Out:
# 0.9059774993582276
